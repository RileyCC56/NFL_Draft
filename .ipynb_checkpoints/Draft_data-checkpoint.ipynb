# %%
# Import data manipulation modules
import pandas as pd
import os
import numpy as np
import seaborn as sns

# Import data visualization modules
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
draft_df = pd.read_csv('./Resources/Draft_data.csv')
draft_df.head()
# Out:
#    Year  Rnd  Pick                    Player Pos  DrAge   Tm  From    To  AP1  \
# 0  2021    1     1  Trevor Lawrence\LawrTr00  QB   21.0  JAX  2021  2021    0
# 1  2021    1     2      Zach Wilson\WilsZa00  QB   22.0  NYJ  2021  2021    0
# 2  2021    1     3       Trey Lance\LancTr00  QB   21.0  SFO  2021  2021    0
# 3  2021    1     4       Kyle Pitts\PittKy00  TE   20.0  ATL  2021  2021    0
# 4  2021    1     5    Ja'Marr Chase\ChasJa00  WR   21.0  CIN  2021  2021    0
#
#    PB  St  CarAV   G  GS      College/Univ
# 0   0   0      0   9   9           Clemson
# 1   0   0      0   6   6               BYU
# 2   0   0      0   4   1  North Dakota St.
# 3   0   0      0  10   9           Florida
# 4   0   0      0   9   9               LSU

# %%
# Determine if there are any missing values in school data
draft_df.count()
# Out:
# Year            5512
# Rnd             5512
# Pick            5512
# Player          5512
# Pos             5512
# DrAge           5511
# Tm              5512
# From            5512
# To              5512
# AP1             5512
# PB              5512
# St              5512
# CarAV           5512
# G               5512
# GS              5512
# College/Univ    5503
# dtype: int64

# %%
# determine data type for DataFrame
draft_df.dtypes
# Out:
# Year              int64
# Rnd               int64
# Pick              int64
# Player           object
# Pos              object
# DrAge           float64
# Tm               object
# From              int64
# To                int64
# AP1               int64
# PB                int64
# St                int64
# CarAV             int64
# G                 int64
# GS                int64
# College/Univ     object
# dtype: object

# %%
draft_df.head(10)
# Out:
#    Year  Rnd  Pick                       Player Pos  DrAge   Tm  From    To  \
# 0  2021    1     1     Trevor Lawrence\LawrTr00  QB   21.0  JAX  2021  2021
# 1  2021    1     2         Zach Wilson\WilsZa00  QB   22.0  NYJ  2021  2021
# 2  2021    1     3          Trey Lance\LancTr00  QB   21.0  SFO  2021  2021
# 3  2021    1     4          Kyle Pitts\PittKy00  TE   20.0  ATL  2021  2021
# 4  2021    1     5       Ja'Marr Chase\ChasJa00  WR   21.0  CIN  2021  2021
# 5  2021    1     6       Jaylen Waddle\WaddJa00  WR   22.0  MIA  2021  2021
# 6  2021    1     7        Penei Sewell\SewePe00  OL   20.0  DET  2021  2021
# 7  2021    1     8         Jaycee Horn\HornJa00  DB   21.0  CAR  2021  2021
# 8  2021    1     9  Patrick Surtain II\SurtPa01  DB   21.0  DEN  2021  2021
# 9  2021    1    10       DeVonta Smith\SmitDe07  WR   22.0  PHI  2021  2021
#
#    AP1  PB  St  CarAV   G  GS      College/Univ
# 0    0   0   0      0   9   9           Clemson
# 1    0   0   0      0   6   6               BYU
# 2    0   0   0      0   4   1  North Dakota St.
# 3    0   0   0      0  10   9           Florida
# 4    0   0   0      0   9   9               LSU
# 5    0   0   0      0  10  10           Alabama
# 6    0   0   0      0   9   9            Oregon
# 7    0   0   0      0   3   3    South Carolina
# 8    0   0   0      0  10   9           Alabama
# 9    0   0   0      0  10  10           Alabama

# %%
#Change Column names
draft_df.rename(columns ={ 'Rnd': 'Round',
                          'Year': 'Draft Year',
                          'Pos':'Position',
                          'DrAge':'Draft Age',
                          'Tm':'Team',
                          'From':'Start Year',
                          'To':'End Year',
                          'AP1': "First Team All-Pro",
                          'PB':'Pro-Bowl Selections',
                          'St':"Starter Years",
                          'CarAV': 'Career Approxmiate Value',
                          'G':'Games Played',
                          'GS':"Games Started" }, inplace=True)
draft_df.head()
# Out:
#    Draft Year  Round  Pick                    Player Position  Draft Age Team  \
# 0        2021      1     1  Trevor Lawrence\LawrTr00       QB       21.0  JAX
# 1        2021      1     2      Zach Wilson\WilsZa00       QB       22.0  NYJ
# 2        2021      1     3       Trey Lance\LancTr00       QB       21.0  SFO
# 3        2021      1     4       Kyle Pitts\PittKy00       TE       20.0  ATL
# 4        2021      1     5    Ja'Marr Chase\ChasJa00       WR       21.0  CIN
#
#    Start Year  End Year  First Team All-Pro  Pro-Bowl Selections  \
# 0        2021      2021                   0                    0
# 1        2021      2021                   0                    0
# 2        2021      2021                   0                    0
# 3        2021      2021                   0                    0
# 4        2021      2021                   0                    0
#
#    Starter Years  Career Approxmiate Value  Games Played  Games Started  \
# 0              0                         0             9              9
# 1              0                         0             6              6
# 2              0                         0             4              1
# 3              0                         0            10              9
# 4              0                         0             9              9
#
#        College/Univ
# 0           Clemson
# 1               BYU
# 2  North Dakota St.
# 3           Florida
# 4               LSU

# %%
#create career length column 
draft_df["Career Length (Years)"] = draft_df["End Year"] - draft_df["Start Year"]
draft_df.tail(10)
# Out:
#       Draft Year  Round  Pick                    Player Position  Draft Age  \
# 5502        2000      7   245      Danny Clark\ClarDa21       LB       23.0
# 5503        2000      7   246              Leroy Fields       WR        0.0
# 5504        2000      7   247            Mark Baniewicz        T        0.0
# 5505        2000      7   248      Lewis Kelly\KellLe21        T       23.0
# 5506        2000      7   249  Eugene McCaslin\McCaEu20       LB       23.0
# 5507        2000      7   250              Ethan Howell       WR        0.0
# 5508        2000      7   251      DaShon Polk\PolkDa20       LB       23.0
# 5509        2000      7   252   Rondell Mealey\MealRo00       RB       23.0
# 5510        2000      7   253    Alfonso Boone\BoonAl20       DT       24.0
# 5511        2000      7   254    Michael Green\GreeMi20       DB       23.0
#
#      Team  Start Year  End Year  First Team All-Pro  Pro-Bowl Selections  \
# 5502  JAX        2000      2010                   0                    0
# 5503  DEN        2000      2000                   0                    0
# 5504  JAX        2000      2000                   0                    0
# 5505  MIN        2001      2005                   0                    0
# 5506  GNB        2000      2000                   0                    0
# 5507  WAS        2000      2000                   0                    0
# 5508  BUF        2000      2006                   0                    0
# 5509  GNB        2001      2002                   0                    0
# 5510  DET        2001      2010                   0                    0
# 5511  CHI        2000      2008                   0                    0
#
#       Starter Years  Career Approxmiate Value  Games Played  Games Started  \
# 5502              8                        39           168            102
# 5503              0                         0             0              0
# 5504              0                         0             0              0
# 5505              0                         4            18              5
# 5506              0                         0             1              0
# 5507              0                         0             0              0
# 5508              1                        10            95             16
# 5509              0                         2            14              1
# 5510              1                        23           129             41
# 5511              2                        22           104             48
#
#                College/Univ  Career Length (Years)
# 5502               Illinois                     10
# 5503            Jackson St.                      0
# 5504               Syracuse                      0
# 5505     South Carolina St.                      4
# 5506                Florida                      0
# 5507           Oklahoma St.                      0
# 5508                Arizona                      6
# 5509                    LSU                      1
# 5510   Mount San Antonio JC                      9
# 5511  Northwestern St. (LA)                      8

# %%
#Find how many positions there were in total
draft_df.Position.value_counts()
# Out:
# DB     798
# WR     717
# LB     594
# DE     493
# RB     454
# DT     428
# T      418
# TE     322
# G      289
# QB     270
# CB     189
# C      138
# S      128
# OL      74
# OLB     73
# FB      48
# DL      45
# ILB     34
# Name: Position, dtype: int64

# %%
#replace and merge Positions
draft_df.loc[draft_df.Position =='NT',"Position"] = "DL"
draft_df.loc[draft_df.Position =='DE',"Position"] = "DL"
draft_df.loc[draft_df.Position =='DT',"Position"] = "DL"

# %%
#replace and merge Positions
draft_df.loc[draft_df.Position =='OLB',"Position"] = "LB"
draft_df.loc[draft_df.Position =='ILB',"Position"] = "LB"

# %%
#replace and merge Positions
draft_df.loc[draft_df.Position =='T',"Position"] = "OL"
draft_df.loc[draft_df.Position =='C',"Position"] = "OL"
draft_df.loc[draft_df.Position =='G',"Position"] = "OL"

# %%
draft_df.Position.value_counts()
# Out:
# DL    966
# OL    919
# DB    798
# WR    717
# LB    701
# RB    454
# TE    322
# QB    270
# CB    189
# S     128
# FB     48
# Name: Position, dtype: int64

# %%
# get data for drafts from 2000 to 2010
#draft_df_2010 = draft_df.loc[draft_df.Draft_Yr <= 2010, :]

# %%
# set the font scaling and the plot sizes
sns.set(font_scale=1.65)
rcParams["figure.figsize"] = 12,9

# %%
# Use distplot to view the distribu
#sns.distplot(draft_df)
#plt.title("Distribution of Career Approximate Value")
#plt.xlim(-5,150)
#plt.show()

# %%
sns.boxplot(x="Position", y="Career Approxmiate Value", data=draft_df)
plt.title("Distribution of Career Approximate Value by Position (2000-2020)")
plt.show()

# %%
sns.boxplot(x="Position", y="Career Length (Years)", data=draft_df)
plt.title("Distribution of Career Length by Position (2000-2020)")
plt.show()

# %% [markdown]
# # Positional Dataframes

# %%
#QB data frame
QB_df = draft_df[draft_df["Position"] == "QB"]
QB_df.head()
# Out:
#     Draft Year  Round  Pick                    Player Position  Draft Age  \
# 0         2021      1     1  Trevor Lawrence\LawrTr00       QB       21.0
# 1         2021      1     2      Zach Wilson\WilsZa00       QB       22.0
# 2         2021      1     3       Trey Lance\LancTr00       QB       21.0
# 10        2021      1    11    Justin Fields\FielJu00       QB       22.0
# 14        2021      1    15        Mac Jones\JoneMa05       QB       23.0
#
#    Team  Start Year  End Year  First Team All-Pro  Pro-Bowl Selections  \
# 0   JAX        2021      2021                   0                    0
# 1   NYJ        2021      2021                   0                    0
# 2   SFO        2021      2021                   0                    0
# 10  CHI        2021      2021                   0                    0
# 14  NWE        2021      2021                   0                    0
#
#     Starter Years  Career Approxmiate Value  Games Played  Games Started  \
# 0               0                         0             9              9
# 1               0                         0             6              6
# 2               0                         0             4              1
# 10              0                         0             9              7
# 14              1                         0            11             11
#
#         College/Univ  Career Length (Years)
# 0            Clemson                      0
# 1                BYU                      0
# 2   North Dakota St.                      0
# 10          Ohio St.                      0
# 14           Alabama                      0

# %%
#RB DataFrame
RB_df = draft_df[draft_df["Position"] == "RB"]
RB_df.head()
# Out:
#      Draft Year  Round  Pick                     Player Position  Draft Age  \
# 23         2021      1    24      Najee Harris\HarrNa00       RB       23.0
# 24         2021      1    25    Travis Etienne\EtieTr00       RB       22.0
# 34         2021      2    35  Javonte Williams\WillJa10       RB       21.0
# 87         2021      3    88       Trey Sermon\SermTr00       RB       22.0
# 106        2021      4   107    Michael Carter\CartMi03       RB       22.0
#
#     Team  Start Year  End Year  First Team All-Pro  Pro-Bowl Selections  \
# 23   PIT        2021      2021                   0                    0
# 24   JAX        2021      2021                   0                    0
# 34   DEN        2021      2021                   0                    0
# 87   SFO        2021      2021                   0                    0
# 106  NYJ        2021      2021                   0                    0
#
#      Starter Years  Career Approxmiate Value  Games Played  Games Started  \
# 23               0                         0             9              9
# 24               0                         0             0              0
# 34               0                         0            10              0
# 87               0                         0             7              2
# 106              0                         0             9              6
#
#        College/Univ  Career Length (Years)
# 23          Alabama                      0
# 24          Clemson                      0
# 34   North Carolina                      0
# 87         Ohio St.                      0
# 106  North Carolina                      0

# %%
#FB dataframe
FB_df = draft_df[draft_df["Position"] == "FB"]
FB_df.head()
# Out:
#       Draft Year  Round  Pick                     Player Position  Draft Age  \
# 182         2021      5   184         Ben Mason\MasoBe00       FB       22.0
# 1192        2017      6   192        Alex Armah\ArmaAl00       FB       23.0
# 1206        2017      6   206        Sam Rogers\RogeSa00       FB       22.0
# 1237        2017      7   240  Marquez Williams\WillMa09       FB       23.0
# 1425        2016      6   176     Andy Janovich\JanoAn00       FB       23.0
#
#      Team  Start Year  End Year  First Team All-Pro  Pro-Bowl Selections  \
# 182   BAL        2021      2021                   0                    0
# 1192  CAR        2017      2021                   0                    0
# 1206  LAR        2017      2017                   0                    0
# 1237  JAX        2017      2017                   0                    0
# 1425  DEN        2016      2021                   0                    0
#
#       Starter Years  Career Approxmiate Value  Games Played  Games Started  \
# 182               0                         0             0              0
# 1192              0                         0            65              6
# 1206              0                         0             0              0
# 1237              0                         0             1              0
# 1425              1                         2            71             24
#
#        College/Univ  Career Length (Years)
# 182        Michigan                      0
# 1192   West Georgia                      4
# 1206  Virginia Tech                      0
# 1237     Miami (FL)                      0
# 1425       Nebraska                      5

# %%
#WR Dataframe
WR_df = draft_df[draft_df["Position"] == "WR"]
WR_df.head()
# Out:
#     Draft Year  Round  Pick                   Player Position  Draft Age Team  \
# 4         2021      1     5   Ja'Marr Chase\ChasJa00       WR       21.0  CIN
# 5         2021      1     6   Jaylen Waddle\WaddJa00       WR       22.0  MIA
# 9         2021      1    10   DeVonta Smith\SmitDe07       WR       22.0  PHI
# 19        2021      1    20  Kadarius Toney\ToneKa00       WR       22.0  NYG
# 26        2021      1    27  Rashod Bateman\BateRa00       WR       21.0  BAL
#
#     Start Year  End Year  First Team All-Pro  Pro-Bowl Selections  \
# 4         2021      2021                   0                    0
# 5         2021      2021                   0                    0
# 9         2021      2021                   0                    0
# 19        2021      2021                   0                    0
# 26        2021      2021                   0                    0
#
#     Starter Years  Career Approxmiate Value  Games Played  Games Started  \
# 4               0                         0             9              9
# 5               0                         0            10             10
# 9               0                         0            10             10
# 19              0                         0             8              3
# 26              0                         0             4              1
#
#    College/Univ  Career Length (Years)
# 4           LSU                      0
# 5       Alabama                      0
# 9       Alabama                      0
# 19      Florida                      0
# 26    Minnesota                      0

# %%
#TE Dataframe
TE_df = draft_df[draft_df["Position"] == "TE"]
TE_df.head()
# Out:
#     Draft Year  Round  Pick                   Player Position  Draft Age Team  \
# 3         2021      1     4      Kyle Pitts\PittKy00       TE       20.0  ATL
# 54        2021      2    55  Pat Freiermuth\FreiPa00       TE       22.0  PIT
# 80        2021      3    81     Hunter Long\LongHu00       TE       23.0  MIA
# 82        2021      3    83   Tommy Tremble\TremTo00       TE       21.0  CAR
# 96        2021      3    97    Tre' McKitty\McKiTr00       TE       22.0  LAC
#
#     Start Year  End Year  First Team All-Pro  Pro-Bowl Selections  \
# 3         2021      2021                   0                    0
# 54        2021      2021                   0                    0
# 80        2021      2021                   0                    0
# 82        2021      2021                   0                    0
# 96        2021      2021                   0                    0
#
#     Starter Years  Career Approxmiate Value  Games Played  Games Started  \
# 3               0                         0            10              9
# 54              0                         0             9              5
# 80              0                         0             3              1
# 82              0                         0            10              8
# 96              0                         0             3              1
#
#    College/Univ  Career Length (Years)
# 3       Florida                      0
# 54     Penn St.                      0
# 80  Boston Col.                      0
# 82   Notre Dame                      0
# 96      Georgia                      0

# %%
#OL Dataframe
OL_df = draft_df[draft_df["Position"] == "OL"]
OL_df.head()
# Out:
#     Draft Year  Round  Pick                       Player Position  Draft Age  \
# 6         2021      1     7        Penei Sewell\SewePe00       OL       20.0
# 12        2021      1    13      Rashawn Slater\SlatRa00       OL       22.0
# 13        2021      1    14  Alijah Vera-Tucker\VeraAl00       OL       22.0
# 16        2021      1    17    Alex Leatherwood\LeatAl00       OL       22.0
# 22        2021      1    23  Christian Darrisaw\DarrCh00       OL       22.0
#
#    Team  Start Year  End Year  First Team All-Pro  Pro-Bowl Selections  \
# 6   DET        2021      2021                   0                    0
# 12  LAC        2021      2021                   0                    0
# 13  NYJ        2021      2021                   0                    0
# 16  LVR        2021      2021                   0                    0
# 22  MIN        2021      2021                   0                    0
#
#     Starter Years  Career Approxmiate Value  Games Played  Games Started  \
# 6               0                         0             9              9
# 12              0                         0             9              9
# 13              0                         0             9              9
# 16              0                         0             9              9
# 22              0                         0             6              4
#
#      College/Univ  Career Length (Years)
# 6          Oregon                      0
# 12   Northwestern                      0
# 13            USC                      0
# 16        Alabama                      0
# 22  Virginia Tech                      0

# %%
#DL Dataframe
DL_df = draft_df[draft_df["Position"] == "DL"]
DL_df.head()
# Out:
#     Draft Year  Round  Pick                     Player Position  Draft Age  \
# 17        2021      1    18   Jaelan Phillips\PhilJa02       DL       22.0
# 20        2021      1    21        Kwity Paye\PayeKw00       DL       22.0
# 27        2021      1    28     Payton Turner\TurnPa02       DL       23.0
# 29        2021      1    30  Gregory Rousseau\RousGr00       DL       21.0
# 30        2021      1    31        Odafe Oweh\OwehJa00       DL       22.0
#
#    Team  Start Year  End Year  First Team All-Pro  Pro-Bowl Selections  \
# 17  MIA        2021      2021                   0                    0
# 20  IND        2021      2021                   0                    0
# 27  NOR        2021      2021                   0                    0
# 29  BUF        2021      2021                   0                    0
# 30  BAL        2021      2021                   0                    0
#
#     Starter Years  Career Approxmiate Value  Games Played  Games Started  \
# 17              0                         0            10              4
# 20              0                         0             8              8
# 27              0                         0             5              0
# 29              0                         0             9              9
# 30              0                         0             9              1
#
#    College/Univ  Career Length (Years)
# 17   Miami (FL)                      0
# 20     Michigan                      0
# 27      Houston                      0
# 29   Miami (FL)                      0
# 30     Penn St.                      0

# %%
#DB Dataframe
Db_df = draft_df[draft_df["Position"] == "DB"]
Db_df.head()
# Out:
#     Draft Year  Round  Pick                       Player Position  Draft Age  \
# 7         2021      1     8         Jaycee Horn\HornJa00       DB       21.0
# 8         2021      1     9  Patrick Surtain II\SurtPa01       DB       21.0
# 21        2021      1    22        Caleb Farley\FarlCa00       DB       22.0
# 25        2021      1    26     Greg Newsome II\NewsGr00       DB       21.0
# 28        2021      1    29         Eric Stokes\StokEr00       DB       22.0
#
#    Team  Start Year  End Year  First Team All-Pro  Pro-Bowl Selections  \
# 7   CAR        2021      2021                   0                    0
# 8   DEN        2021      2021                   0                    0
# 21  TEN        2021      2021                   0                    0
# 25  CLE        2021      2021                   0                    0
# 28  GNB        2021      2021                   0                    0
#
#     Starter Years  Career Approxmiate Value  Games Played  Games Started  \
# 7               0                         0             3              3
# 8               0                         0            10              9
# 21              0                         0             3              1
# 25              0                         0             8              7
# 28              0                         0             9              7
#
#       College/Univ  Career Length (Years)
# 7   South Carolina                      0
# 8          Alabama                      0
# 21   Virginia Tech                      0
# 25    Northwestern                      0
# 28         Georgia                      0

# %%
#CB dataframe
Cb_df = draft_df[draft_df["Position"] == "CB"]
Cb_df.head()
# Out:
#      Draft Year  Round  Pick                     Player Position  Draft Age  \
# 75         2021      3    76     Paulson Adebo\AdebPa00       CB       22.0
# 103        2021      3   104  Brandon Stephens\StepBr01       CB       23.0
# 107        2021      4   108       Darren Hall\HallDa03       CB       21.0
# 124        2021      4   125      Camryn Bynum\BynuCa00       CB       23.0
# 135        2021      4   136      Marco Wilson\WilsMa04       CB       22.0
#
#     Team  Start Year  End Year  First Team All-Pro  Pro-Bowl Selections  \
# 75   NOR        2021      2021                   0                    0
# 103  BAL        2021      2021                   0                    0
# 107  ATL        2021      2021                   0                    0
# 124  MIN        2021      2021                   0                    0
# 135  ARI        2021      2021                   0                    0
#
#      Starter Years  Career Approxmiate Value  Games Played  Games Started  \
# 75               0                         0             9              9
# 103              0                         0             9              3
# 107              0                         0             7              0
# 124              0                         0             9              2
# 135              0                         0             9              9
#
#       College/Univ  Career Length (Years)
# 75        Stanford                      0
# 103            SMU                      0
# 107  San Diego St.                      0
# 124     California                      0
# 135        Florida                      0

# %%
#LB dataframe
Lb_df = draft_df[draft_df["Position"] == "LB"]
Lb_df.head()
# Out:
#     Draft Year  Round  Pick                       Player Position  Draft Age  \
# 11        2021      1    12       Micah Parsons\ParsMi00       LB       22.0
# 15        2021      1    16       Zaven Collins\CollZa00       LB       22.0
# 18        2021      1    19         Jamin Davis\DaviJa11       LB       22.0
# 31        2021      1    32  Joe Tryon-Shoyinka\TryoJo00       LB       22.0
# 49        2021      2    50       Azeez Ojulari\OjulAz00       LB       21.0
#
#    Team  Start Year  End Year  First Team All-Pro  Pro-Bowl Selections  \
# 11  DAL        2021      2021                   0                    0
# 15  ARI        2021      2021                   0                    0
# 18  WAS        2021      2021                   0                    0
# 31  TAM        2021      2021                   0                    0
# 49  NYG        2021      2021                   0                    0
#
#     Starter Years  Career Approxmiate Value  Games Played  Games Started  \
# 11              0                         0             9              9
# 15              0                         0            10              5
# 18              0                         0             9              4
# 31              0                         0             9              3
# 49              0                         0             9              6
#
#    College/Univ  Career Length (Years)
# 11     Penn St.                      0
# 15        Tulsa                      0
# 18     Kentucky                      0
# 31   Washington                      0
# 49      Georgia                      0

# %%
#S dataframe
S_df = draft_df[draft_df["Position"] == "S"]
S_df.head()
# Out:
#      Draft Year  Round  Pick                    Player Position  Draft Age  \
# 35         2021      2    36    Jevon Holland\HollJe02        S       21.0
# 42         2021      2    43   Trevon Moehrig\MoehTr00        S       22.0
# 142        2021      4   143  Tyree Gillespie\GillTy00        S       23.0
# 152        2021      5   154   Michael Carter\CartMi02        S       22.0
# 161        2021      5   163  Darrick Forrest\ForrDa00        S       22.0
#
#     Team  Start Year  End Year  First Team All-Pro  Pro-Bowl Selections  \
# 35   MIA        2021      2021                   0                    0
# 42   LVR        2021      2021                   0                    0
# 142  LVR        2021      2021                   0                    0
# 152  NYJ        2021      2021                   0                    0
# 161  WAS        2021      2021                   0                    0
#
#      Starter Years  Career Approxmiate Value  Games Played  Games Started  \
# 35               0                         0            10              7
# 42               0                         0             9              9
# 142              0                         0             8              0
# 152              0                         0             9              3
# 161              0                         0             1              0
#
#     College/Univ  Career Length (Years)
# 35        Oregon                      0
# 42           TCU                      0
# 142     Missouri                      0
# 152         Duke                      0
# 161   Cincinnati                      0

# %%
#QB data 
sns.boxplot(x="Round", y="Career Length (Years)", data=qb_df)
plt.title("Distribution of Career Length by Position (2000-2020)")
plt.show()

# %%
qb_df[["Career Length (Years)", 'Pro-Bowl Selections', 'Starter Years','Career Approxmiate Value','Games Played','Games Started']].describe()
# Out:
#        Career Length (Years)  Pro-Bowl Selections  Starter Years  \
# count             270.000000           270.000000     270.000000
# mean                3.762963             0.451852       1.714815
# std                 4.481614             1.621044       3.345663
# min                 0.000000             0.000000       0.000000
# 25%                 0.000000             0.000000       0.000000
# 50%                 2.000000             0.000000       0.000000
# 75%                 6.000000             0.000000       2.000000
# max                21.000000            14.000000      19.000000
#
#        Career Approxmiate Value  Games Played  Games Started
# count                270.000000    270.000000     270.000000
# mean                  16.988889     34.807407      28.292593
# std                   31.934352     52.922894      51.222159
# min                   -4.000000      0.000000       0.000000
# 25%                    0.000000      1.000000       0.000000
# 50%                    2.000000     13.000000       7.000000
# 75%                   16.000000     49.000000      33.000000
# max                  182.000000    310.000000     308.000000

# %%
qb_df.describe(include='all')
# Out:
#          Draft Year       Round        Pick               Player Position  \
# count    270.000000  270.000000  270.000000                  270      270
# unique          NaN         NaN         NaN                  270        1
# top             NaN         NaN         NaN  Colt McCoy\McCoCo00       QB
# freq            NaN         NaN         NaN                    1      270
# mean    2010.137037    3.937037  117.381481                  NaN      NaN
# std        6.345660    2.194899   81.408550                  NaN      NaN
# min     2000.000000    1.000000    1.000000                  NaN      NaN
# 25%     2004.250000    2.000000   36.000000                  NaN      NaN
# 50%     2010.000000    4.000000  118.500000                  NaN      NaN
# 75%     2016.000000    6.000000  191.750000                  NaN      NaN
# max     2021.000000    7.000000  253.000000                  NaN      NaN
#
#          Draft Age Team   Start Year     End Year  First Team All-Pro  \
# count   270.000000  270   270.000000   270.000000          270.000000
# unique         NaN   34          NaN          NaN                 NaN
# top            NaN  NYJ          NaN          NaN                 NaN
# freq           NaN   14          NaN          NaN                 NaN
# mean     21.122222  NaN  2010.400000  2014.162963            0.040741
# std       6.064390  NaN     6.391444     6.316565            0.289544
# min       0.000000  NaN  2000.000000  2000.000000            0.000000
# 25%      22.000000  NaN  2005.000000  2009.000000            0.000000
# 50%      23.000000  NaN  2010.000000  2015.000000            0.000000
# 75%      23.000000  NaN  2016.000000  2020.000000            0.000000
# max      29.000000  NaN  2021.000000  2021.000000            3.000000
#
#         Pro-Bowl Selections  Starter Years  Career Approxmiate Value  \
# count            270.000000     270.000000                270.000000
# unique                  NaN            NaN                       NaN
# top                     NaN            NaN                       NaN
# freq                    NaN            NaN                       NaN
# mean               0.451852       1.714815                 16.988889
# std                1.621044       3.345663                 31.934352
# min                0.000000       0.000000                 -4.000000
# 25%                0.000000       0.000000                  0.000000
# 50%                0.000000       0.000000                  2.000000
# 75%                0.000000       2.000000                 16.000000
# max               14.000000      19.000000                182.000000
#
#         Games Played  Games Started College/Univ  Career Length (Years)
# count     270.000000     270.000000          270             270.000000
# unique           NaN            NaN          115                    NaN
# top              NaN            NaN          LSU                    NaN
# freq             NaN            NaN            9                    NaN
# mean       34.807407      28.292593          NaN               3.762963
# std        52.922894      51.222159          NaN               4.481614
# min         0.000000       0.000000          NaN               0.000000
# 25%         1.000000       0.000000          NaN               0.000000
# 50%        13.000000       7.000000          NaN               2.000000
# 75%        49.000000      33.000000          NaN               6.000000
# max       310.000000     308.000000          NaN              21.000000

# %%
# Out:
# 3.937037037037037

# %%
lm = sns.boxplot(x="Round", y="Career Length (Years)", data=draft_df, col="Position",
                col_wrap=5, size=4, line_kws={"color": "black"},
                scatter_kws={"color": sns.color_palette()[5], "alpha": 0.7})

# add title to the plot (which is a FacetGrid)
# https://stackoverflow.com/questions/29813694/how-to-add-a-title-to-seaborn-facet-plot
plt.subplots_adjust(top=0.9)
lm.fig.suptitle("Career Approximate Value by Pick and Position",
                fontsize=30)

plt.xlim(-5, 500)
plt.ylim(-1, 100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-689ca1f6c3ce> in <module>
# ----> 1 lm = sns.boxplot(x="Round", y="Career Length (Years)", data=draft_df, col="Position",
#       2                 col_wrap=5, size=4, line_kws={"color": "black"},
#       3                 scatter_kws={"color": sns.color_palette()[5], "alpha": 0.7})
#       4
#       5 # add title to the plot (which is a FacetGrid)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\envs\PythonData\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2249     kwargs.update(dict(whis=whis))
#    2250
# -> 2251     plotter.plot(ax, kwargs)
#    2252     return ax
#    2253
#
# ~\anaconda3\envs\PythonData\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     507     def plot(self, ax, boxplot_kws):
#     508         """Make the plot."""
# --> 509         self.draw_boxplot(ax, boxplot_kws)
#     510         self.annotate_axes(ax)
#     511         if self.orient == "h":
#
# ~\anaconda3\envs\PythonData\lib\site-packages\seaborn\categorical.py in draw_boxplot(self, ax, kws)
#     439                     continue
#     440
# --> 441                 artist_dict = ax.boxplot(box_data,
#     442                                          vert=vert,
#     443                                          patch_artist=True,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: boxplot() got an unexpected keyword argument 'col'
