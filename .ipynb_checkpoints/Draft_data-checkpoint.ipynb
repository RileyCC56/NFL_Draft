# %%
# Import data manipulation modules
import pandas as pd
import os
import numpy as np
import seaborn as sns

# Import data visualization modules
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
draft_df = pd.read_csv('./Resources/Draft_data.csv')
draft_df.head()
# Out:
#    Year  Rnd  Pick                    Player Pos  DrAge   Tm  From    To  AP1  \
# 0  2021    1     1  Trevor Lawrence\LawrTr00  QB   21.0  JAX  2021  2021    0
# 1  2021    1     2      Zach Wilson\WilsZa00  QB   22.0  NYJ  2021  2021    0
# 2  2021    1     3       Trey Lance\LancTr00  QB   21.0  SFO  2021  2021    0
# 3  2021    1     4       Kyle Pitts\PittKy00  TE   20.0  ATL  2021  2021    0
# 4  2021    1     5    Ja'Marr Chase\ChasJa00  WR   21.0  CIN  2021  2021    0
#
#    PB  St  CarAV   G  GS      College/Univ
# 0   0   0      0   9   9           Clemson
# 1   0   0      0   6   6               BYU
# 2   0   0      0   4   1  North Dakota St.
# 3   0   0      0  10   9           Florida
# 4   0   0      0   9   9               LSU

# %%
# Determine if there are any missing values in school data
draft_df.count()
# Out:
# Year            5512
# Rnd             5512
# Pick            5512
# Player          5512
# Pos             5512
# DrAge           5511
# Tm              5512
# From            5512
# To              5512
# AP1             5512
# PB              5512
# St              5512
# CarAV           5512
# G               5512
# GS              5512
# College/Univ    5503
# dtype: int64

# %%
# determine data type for DataFrame
draft_df.dtypes
# Out:
# Year              int64
# Rnd               int64
# Pick              int64
# Player           object
# Pos              object
# DrAge           float64
# Tm               object
# From              int64
# To                int64
# AP1               int64
# PB                int64
# St                int64
# CarAV             int64
# G                 int64
# GS                int64
# College/Univ     object
# dtype: object

# %%
draft_df.head(10)
# Out:
#    Year  Rnd  Pick                       Player Pos  DrAge   Tm  From    To  \
# 0  2021    1     1     Trevor Lawrence\LawrTr00  QB   21.0  JAX  2021  2021
# 1  2021    1     2         Zach Wilson\WilsZa00  QB   22.0  NYJ  2021  2021
# 2  2021    1     3          Trey Lance\LancTr00  QB   21.0  SFO  2021  2021
# 3  2021    1     4          Kyle Pitts\PittKy00  TE   20.0  ATL  2021  2021
# 4  2021    1     5       Ja'Marr Chase\ChasJa00  WR   21.0  CIN  2021  2021
# 5  2021    1     6       Jaylen Waddle\WaddJa00  WR   22.0  MIA  2021  2021
# 6  2021    1     7        Penei Sewell\SewePe00  OL   20.0  DET  2021  2021
# 7  2021    1     8         Jaycee Horn\HornJa00  DB   21.0  CAR  2021  2021
# 8  2021    1     9  Patrick Surtain II\SurtPa01  DB   21.0  DEN  2021  2021
# 9  2021    1    10       DeVonta Smith\SmitDe07  WR   22.0  PHI  2021  2021
#
#    AP1  PB  St  CarAV   G  GS      College/Univ
# 0    0   0   0      0   9   9           Clemson
# ...

# %%
draft_df.Pos.value_counts()
# Out:
# DB     798
# WR     717
# LB     594
# DE     493
# RB     454
# DT     428
# T      418
# TE     322
# G      289
# QB     270
# CB     189
# C      138
# S      128
# OL      74
# OLB     73
# FB      48
# ILB     34
# DL      31
# NT      14
# Name: Pos, dtype: int64

# %%
#replace and merge Positions
#draft_df.loc[draft_df.Pos =='NT',"Pos"] = "DL"

# %%
#create career length column based on To and From columns

# %%
# Analyze CarAV by draft Round
#Early rounds trend towards producing better players
sns.boxplot(x = "Rnd", y = "CarAV", data = draft_df)
# Out:
# <AxesSubplot:xlabel='Rnd', ylabel='CarAV'>

# %%
#Dataframe from 2000-2010 drafted players
draft_before_2010 = draft_df[draft_df['Year'] < 2011]
draft_before_2010["Years Played"] = draft_before_2010["To"] - draft_before_2010["Year"]
draft_before_2010.head(10)
# Out:
# <ipython-input-12-8a4184a8a8d1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   draft_before_2010["Years Played"] = draft_before_2010["To"] - draft_before_2010["Year"]
#       Year  Rnd  Pick                    Player Pos  DrAge   Tm  From    To  \
# 2755  2010    1     1     Sam Bradford\BradSa00  QB   22.0  STL  2010  2018
# 2756  2010    1     2    Ndamukong Suh\SuhxNd99  DT   23.0  DET  2010  2021
# 2757  2010    1     3     Gerald McCoy\McCoGe99  DT   22.0  TAM  2010  2021
# 2758  2010    1     4   Trent Williams\WillTr21   T   22.0  WAS  2010  2021
# 2759  2010    1     5       Eric Berry\BerrEr99  DB   21.0  KAN  2010  2018
# 2760  2010    1     6    Russell Okung\OkunRu20   T   21.0  SEA  2010  2020
# ...

# %%
#create a QB DF
QB_df = draft_before_2010[draft_before_2010["Pos"]=='QB']
QB_df.head(10)
# Out:
#       Year  Rnd  Pick                      Player Pos  DrAge   Tm  From    To  \
# 2755  2010    1     1       Sam Bradford\BradSa00  QB   22.0  STL  2010  2018
# 2779  2010    1    25          Tim Tebow\TeboTi00  QB   23.0  DEN  2010  2012
# 2802  2010    2    48      Jimmy Clausen\ClauJi00  QB   22.0  CAR  2010  2015
# 2839  2010    3    85         Colt McCoy\McCoCo00  QB   24.0  CLE  2010  2021
# 2876  2010    4   122         Mike Kafka\KafkMi00  QB   23.0  PHI  2011  2011
# 2908  2010    5   155       John Skelton\SkelJo00  QB   22.0  ARI  2010  2012
# 2921  2010    5   168  Jonathan Crompton\CromJo00  QB   23.0  SDG  2010     0
# 2928  2010    6   176        Rusty Smith\SmitRu01  QB   23.0  TEN  2010  2012
# 2933  2010    6   181       Dan LeFevour\LeFeDa00  QB   23.0  CHI  2010     0
# 2956  2010    6   204          Tony Pike\PikeTo00  QB   24.0  CAR  2010  2010
#
#       AP1  PB  St  CarAV   G  GS      College/Univ  Years Played
# ...

# %%
QB_df.tail(10)
# Out:
#       Year  Rnd  Pick                    Player Pos  DrAge   Tm  From    To  \
# 5335  2000    3    75     Chris Redman\RedmCh00  QB   23.0  BAL  2000  2011
# 5422  2000    5   163       Tee Martin\MartTe00  QB   22.0  PIT  2001  2003
# 5427  2000    6   168      Marc Bulger\BulgMa00  QB   23.0  NOR  2002  2009
# 5440  2000    6   183     Spergon Wynn\WynnSp00  QB   22.0  CLE  2000  2001
# 5456  2000    6   199        Tom Brady\BradTo00  QB   23.0  NWE  2000  2021
# 5459  2000    6   202       Todd Husak\HusaTo20  QB   22.0  WAS  2000  2000
# 5462  2000    6   205             JaJuan Seider  QB    0.0  SDG  2000     0
# 5469  2000    7   212       Tim Rattay\RattTi00  QB   23.0  SFO  2000  2007
# 5471  2000    7   214  Jarious Jackson\JackJa01  QB   23.0  DEN  2000  2003
# 5491  2000    7   234     Joe Hamilton\HamiJo20  QB   23.0  TAM  2000  2000
#
#       AP1  PB  St  CarAV    G   GS    College/Univ  Years Played
# 5335    0   0   0      9   31   12      Louisville            11
# ...

# %%
sns.boxplot(x = "Rnd", y = "G", data = QB_df)
# Out:
# <AxesSubplot:xlabel='Rnd', ylabel='G'>
